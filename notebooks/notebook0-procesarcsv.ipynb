# %%
import pandas as pd

# %%
df = pd.read_csv('../spotify-tracks.csv')
df.sample(5)
# Out:
#        Unnamed: 0                track_id                          artists  \
# 71529       71529  3UygY7qW2cvG9Llkay6i1i                      Evanescence
# 96267       96267  249w6QiDEGJ4NqRpb02qoS              Ivete Sangalo;Pablo
# 83936       83936  6HnC8UJ9WqKUwx3dcha5Md           Mat Zo;OLAN;Fred Falke
# 98251       98251  3Rf5q1Ua1Dx031OsCE1XRQ                     Mena Massoud
# 36229       36229  4XANZ0xRF0vGRso3vJZVrF  Lonely in the Rain;Leo Stannard
#
#                                          album_name  \
# 71529                                        Fallen
# 96267                                      Duetos 2
# 83936                       Journey To ABGT500 pt.2
# 98251  Aladdin (Original Motion Picture Soundtrack)
# 36229                                      Drifting
#
#                                    track_name  popularity  duration_ms  \
# 71529                             Going Under          73       214946
# 96267                        Vingança Do Amor          43       178200
# 83936  Colours (ABGT499D3) - Fred Falke Remix          38       202622
# 98251                One Jump Ahead (Reprise)          47        60009
# 36229                                Drifting          60       206646
#
#        explicit  danceability  energy  ...  loudness  mode  speechiness  \
# 71529     False         0.370   0.858  ...    -4.885     0       0.0545
# 96267     False         0.568   0.730  ...    -5.136     1       0.0375
# 83936     False         0.647   0.839  ...    -6.864     0       0.0395
# 98251     False         0.314   0.103  ...   -16.886     1       0.0368
# 36229     False         0.692   0.481  ...    -9.084     1       0.0585
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 71529       0.00815          0.000021    0.2290    0.464  175.077
# 96267       0.20500          0.000000    0.3400    0.530  132.076
# 83936       0.00005          0.499000    0.2020    0.191  122.040
# 98251       0.86700          0.004620    0.0973    0.134   48.991
# 36229       0.13700          0.000000    0.1500    0.367  115.007
#
#        time_signature        track_genre
# 71529               4              metal
# 96267               4              samba
# 83936               4  progressive-house
# 98251               4         show-tunes
# 36229               4             french
#
# [5 rows x 21 columns]

# %% [markdown]
# ## EXPLORANDO LOS DATOS
#
#     Con esta función estaremos calculando que valores son nulos de cada columna.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df.drop(columns="Unnamed: 0", inplace=True)

# %%
df.isna().sum()
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %% [markdown]
# Después de utilizar la funcion `isna` vemos que existen 3 columnas con valor nulo, presuponemos que son la misma fila. Extraemos la fila:

# %%
df[df['album_name'].isna()]
# Out:
#                      track_id artists album_name track_name  popularity  \
# 65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN           0
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 65900            0     False         0.501   0.583    7     -9.46     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature track_genre
# 65900  138.391               4       k-pop

# %% [markdown]
# Tras confirmar que los tres valores nulos pertenecen a la misma fila, decidimos limpiarlos. A continuacion tratamos de ver si existen datos duplicados.

# %%
df.dropna(inplace=True)

# %%
df[df['album_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre]
# Index: []

# %%
df = df.iloc[:50000, :6]

# %% [markdown]
# En el tratamiento inicial de los datos no detectamos duplicados, sin embargo tras trabajar con eld ataset nos dimos cuenta de los duplicados en el track_id.

# %%
df.duplicated().sum()
# Out:
# np.int64(5809)

# %%
df.duplicated(subset="track_id").sum()
# Out:
# np.int64(5810)

# %%
df.drop_duplicates(subset="track_id",inplace=True)

# %%
df
# Out:
#                      track_id                           artists  \
# 0      5SuOikwiRyPMVoIQDJUgSV                       Gen Hoshino
# 1      4qPNDBW1i3p13qLCt0Ki3A                      Ben Woodward
# 2      1iJBSr7s7jYXzM8EGcbK5b            Ingrid Michaelson;ZAYN
# 3      6lfxq3CG4xtTiEg7opyCyx                      Kina Grannis
# 4      5vjLSffimiIP26QG5WcN2K                  Chord Overstreet
# ...                       ...                               ...
# 49991  2GIN5jc5IDdoVujHhC5NDo       Radical Redemption;N-Vitral
# 49992  6E0cm1PEAj4i851YTLsCaH       Adaro;Aftershock;Ava Silver
# 49995  2DWNZunMWTsEoox83agzO2  Noisecontrollers;Bass Modulators
# 49998  2DgNGXMJ92AHIaBWYXI7XW                     Brennan Heart
# 49999  4W26Z7WlOdxPYgu1mJxcD7               Jebroer;Paul Elstak
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                Hold On
# ...                                                  ...
# 49991                             The Road To Redemption
# 49992                                   The Now And Then
# 49995                                         All Around
# 49998                                 Evolution Of Style
# 49999  Kind Van De Duivel Vol. 2 - De Grootste Hardst...
#
#                                      track_name  popularity  duration_ms
# 0                                        Comedy          73       230666
# 1                              Ghost - Acoustic          55       149610
# 2                                To Begin Again          57       210826
# 3                    Can't Help Falling In Love          71       201933
# 4                                       Hold On          82       198853
# ...                                         ...         ...          ...
# 49991                        Hover Through Hell          19       136000
# 49992           The Now And Then - Extended Mix          19       294971
# 49995  Faster N Further - Bass Modulators Remix          19       219871
# 49998          F.I.F.O. (Outbreak Remix) - Edit          19       185600
# 49999                        Kind Eines Teufels          20       203079
#
# [44190 rows x 6 columns]

# %%
df.to_csv("../spotify-clean.csv", index=False)
