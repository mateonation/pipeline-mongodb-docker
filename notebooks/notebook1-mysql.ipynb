# %% [markdown]
# # MySQL

# %% [markdown]
# Leemos el archivo csv y lo almacenamos en un dataframe de pandas

# %%
import pandas as pd

df = pd.read_csv('../spotify-clean.csv')
df.sample(5)
# Out:
#                      track_id              artists  \
# 14146  0OrwGH9aeguhopTVubv0VZ             demxntia
# 19180  4TYeIlwlJTgNkPaFxUP0PJ  Marshmello;Bastille
# 997    1ZD2MlKRTYKI8oewOt28mc           Pigeon Pit
# 30856  55A2PJuVAmaghsWUvfmYtY                Papon
# 16948  0PhVeoHEEaRkar3ToDQz6w        Daniel Deluxe
#
#                                  album_name   track_name  popularity  \
# 14146                             goodnight      tonight          71
# 19180  Tutti in piscina Canzoni per bambini      Happier           1
# 997                               Treehouse    Tall Cans          26
# 30856                           Haaye Rabba  Haaye Rabba          48
# 16948     Ghostrunner (Original Soundtrack)       Dharma          36
#
#        duration_ms
# 14146        84875
# 19180       214289
# 997         186461
# 30856       190975
# 16948       162706

# %% [markdown]
# Antes de conectarnos a nuestra BBDD de MySQL, instalaremos en nuestro environment: `pip install mysql-connector-python`.

# %% [markdown]
# Ahora, nos conectaremos a nuestra BBDD 'pipe' de MySQL y verificamos qué databases están creadas

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="changeme",
  database="pipe"
)

mycursor = mydb.cursor(buffered=True)

mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# ('track',)

# %% [markdown]
# A continuación nos conectaremos a la BBDD 'pipe' y crearemos en ella la tabla 'spotify_tracks'

# %%
mycursor.execute("CREATE TABLE IF NOT EXISTS track (" \
"track_id varchar(250), " \
"track_name varchar(250), " \
"artists varchar(1000)," \
"album_name varchar(5120)," \
"popularity int," \
"duration_ms bigint," \
"PRIMARY KEY (track_id)" \
");")

#Show table structure
mycursor.execute("DESCRIBE track")

for x in mycursor:
  print(x)
# Out:
# ('track_id', 'varchar(250)', 'NO', 'PRI', None, '')
# ('track_name', 'varchar(250)', 'YES', '', None, '')
# ('artists', 'varchar(1000)', 'YES', '', None, '')
# ('album_name', 'varchar(5120)', 'YES', '', None, '')
# ('popularity', 'int', 'YES', '', None, '')
# ('duration_ms', 'bigint', 'YES', '', None, '')

# %% [markdown]
# Comprobamos que la creación de la tabla `tracks` fue correcta. Procedemos a la inserción de los datos de nuestro dataset en la BBDD de MySQL.
#
# Para ello, crearemos un bucle que nos inserte cada dato de nuestro dataframe en la tabla de mysql

# %%
for i in range(len(df)):
    sql = "INSERT INTO track (track_id, track_name, artists, album_name, popularity, duration_ms) VALUES (%s, %s, %s, %s, %s, %s)"
    val = (
        df.iloc[i]['track_id'],
        df.iloc[i]['track_name'],
        df.iloc[i]['artists'],
        df.iloc[i]['album_name'],
        int(df.iloc[i]['popularity']),    # convertir a tipo int nativo
        int(df.iloc[i]['duration_ms'])    # convertir a tipo int nativo
    )
    mycursor.execute(sql, val)
    
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/miniconda3/envs/db/lib/python3.14/site-packages/mysql/connector/connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry '5SuOikwiRyPMVoIQDJUgSV' for key 'track.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[12], line 11
#       2     sql = "INSERT INTO track (track_id, track_name, artists, album_name, popularity, duration_ms) VALUES (%s, %s, %s, %s, %s, %s)"
#       3     val = (
#       4         df.iloc[i]['track_id'],
#       5         df.iloc[i]['track_name'],
#    (...)      9         int(df.iloc[i]['duration_ms'])    # convertir a tipo int nativo
#      10     )
# ---> 11     mycursor.execute(sql, val)
#      13 mydb.commit()
#
# File ~/miniconda3/envs/db/lib/python3.14/site-packages/mysql/connector/cursor_cext.py:353, in CMySQLCursor.execute(self, operation, params, map_results)
#     345 self._executed = (
#     346     self._stmt_partition["single_stmts"].popleft()
#     347     if map_results
#     348     else self._stmt_partition["mappable_stmt"]
#     349 )
#     351 try:
#     352     self._handle_result(
# --> 353         self._connection.cmd_query(
#     354             self._stmt_partition["mappable_stmt"],
#     355             raw=self._raw,
#     356             buffered=self._buffered,
#     357             raw_as_string=self._raw_as_string,
#     358         )
#     359     )
#     360 except MySQLInterfaceError as err:
#     361     if hasattr(err, "errno"):
#
# File ~/miniconda3/envs/db/lib/python3.14/site-packages/mysql/connector/opentelemetry/context_propagation.py:106, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#     103     cnx.query_attrs_append(value=(TRACEPARENT_HEADER_NAME, tp_header))
#     105 try:
# --> 106     result = method(cnx, *args, **kwargs)
#     107 finally:
#     108     if tp_header is not None:
#
# File ~/miniconda3/envs/db/lib/python3.14/site-packages/mysql/connector/connection_cext.py:781, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     779 except MySQLInterfaceError as err:
#     780     if hasattr(err, "errno"):
# --> 781         raise get_mysql_exception(
#     782             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     783         ) from err
#     784     raise InterfaceError(str(err)) from err
#     785 except AttributeError as err:
#
# IntegrityError: 1062 (23000): Duplicate entry '5SuOikwiRyPMVoIQDJUgSV' for key 'track.PRIMARY'
