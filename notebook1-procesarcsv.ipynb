# %%
import pandas as pd

# %%
df = pd.read_csv('spotify-tracks.csv')
df.sample(5)
# Out:
#         Unnamed: 0                track_id         artists  \
# 43428        43428  6qYkNJmU5w4byWrqrXvDjE   Juninho Black
# 102051      102051  6ymoA9aCgqTyoQLIeR7vCX      Taba Chake
# 113968      113968  4yoH9qzZQk1q7tQEiy4v4Y  Lucas Cervetti
# 95211        95211  6nxop4edP4uHU25CnWqqv0      Maelo Ruiz
# 62334        62334  4T6HLdP6OcAtqC6tGnQelG   Michael Bublé
#
#                    album_name  track_name  popularity  duration_ms  explicit  \
# 43428                Temperou    Temperou          28       209826     False
# 102051          Bombay Dreams     Shaayad          52       208000     False
# 113968                  Ámbar     Suspiro          21        89274     False
# 95211              Uniquehits      Te Amo          34       260773     False
# 62334   Call Me Irresponsible  Everything          71       212373     False
#
#         danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df[df['album_name'].isna()]
# Out:
#        Unnamed: 0                track_id artists album_name track_name  \
# 65900       65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN
#
#        popularity  duration_ms  explicit  danceability  energy  ...  loudness  \
# 65900           0            0     False         0.501   0.583  ...     -9.46
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900     0       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature  track_genre
# 65900  138.391               4        k-pop
#
# [1 rows x 21 columns]

# %%
df.dropna(inplace=True)

# %%
df = df.iloc[:50000, :7]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(subset="track_id",inplace=True)

# %%
df
# Out:
#        Unnamed: 0                track_id                           artists  \
# 0               0  5SuOikwiRyPMVoIQDJUgSV                       Gen Hoshino
# 1               1  4qPNDBW1i3p13qLCt0Ki3A                      Ben Woodward
# 2               2  1iJBSr7s7jYXzM8EGcbK5b            Ingrid Michaelson;ZAYN
# 3               3  6lfxq3CG4xtTiEg7opyCyx                      Kina Grannis
# 4               4  5vjLSffimiIP26QG5WcN2K                  Chord Overstreet
# ...           ...                     ...                               ...
# 49991       49991  2GIN5jc5IDdoVujHhC5NDo       Radical Redemption;N-Vitral
# 49992       49992  6E0cm1PEAj4i851YTLsCaH       Adaro;Aftershock;Ava Silver
# 49995       49995  2DWNZunMWTsEoox83agzO2  Noisecontrollers;Bass Modulators
# 49998       49998  2DgNGXMJ92AHIaBWYXI7XW                     Brennan Heart
# 49999       49999  4W26Z7WlOdxPYgu1mJxcD7               Jebroer;Paul Elstak
#
# ...

# %%
df.to_csv("spotify-clean.csv")
