# %%
import pandas as pd

# %%
df = pd.read_csv('spotify-tracks.csv')
df.sample(5)
# Out:
#         Unnamed: 0                track_id  \
# 46521        46521  5urCxi14CYwg44QrqlS1mT
# 104111      104111  5DhPx1cy248eVvTBoTVrrB
# 111590      111590  2amK3MhTpm5vvbENk0K09V
# 13050        13050  2PnEzfFz03XKGU4JqrCw8A
# 6745          6745  7vrHbwWSg3GutLqvpX0JQq
#
#                                            artists  \
# 46521                          Nosferatu;The Viper
# 104111                                  Pol Granch
# 111590                              Massive Attack
# 13050   Felix Da Housecat;The Visionary;Jonas Blue
# 6745                                Anaal Nathrakh
#
#                                  album_name  \
# 46521                              Strength
# 104111                            solo x ti
# 111590                            Collected
# 13050   My Life Is Music (Jonas Blue Remix)
# 6745                            Desideratum
#
#                                   track_name  popularity  duration_ms  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df  = df[df['album_name'].isna()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df  = df[df['album_name']]
#
# File ~/miniconda3/envs/db/lib/python3.14/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniconda3/envs/db/lib/python3.14/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...
