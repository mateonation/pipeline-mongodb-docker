# %%
import pandas as pd

# %%
df = pd.read_csv('spotify-tracks.csv')
df.sample(5)
# Out:
#        Unnamed: 0                track_id            artists  \
# 60131       60131  1zc3ejK8IsDDbUZnDU1hDD              Spice
# 40928       40928  2bgb0Mohm0BFfbWQqiHxTb             J Neto
# 77380       77380  61XyXIWZFWh2zdRBAqVrrE     Sorriso Maroto
# 8921         8921  2Qj1FilGsXITZbFVmVeoLy       Freddie King
# 51725       51725  3WFAdUVTAuLeTMApMwGgvr  Machine Gun Kelly
#
#                                      album_name             track_name  \
# 60131                               Emancipated               CROP TOP
# 40928  A Harpa Cristã (Interpretada por J Neto)       A Ovelha Perdida
# 77380                           A.M.A (Ao Vivo)  Sinal Vital - Ao Vivo
# 8921                   Getting Ready... (World)          I'm Tore Down
# 51725                          Rock & Halloween        born with horns
#
#        popularity  duration_ms  explicit  danceability  energy  ...  loudness  \
# 60131          40       127660      True         0.890   0.794  ...    -6.769
# 40928          37       272277     False         0.414   0.241  ...    -8.760
# 77380          46       239690     False         0.581   0.707  ...    -8.611
# 8921           54       253333     False         0.640   0.496  ...   -11.124
# 51725           4       147943     False         0.569   0.919  ...    -5.378
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 60131     1       0.2030       0.13400          0.000128    0.1330    0.552
# 40928     1       0.0350       0.88400          0.000000    0.1030    0.241
# 77380     1       0.0393       0.73100          0.000004    0.9620    0.423
# 8921      1       0.0413       0.61600          0.000046    0.1830    0.954
# 51725     1       0.1350       0.00089          0.000094    0.0524    0.256
#
#          tempo  time_signature  track_genre
# 60131  102.110               4      j-dance
# 40928  147.548               3       gospel
# 77380  147.963               4       pagode
# 8921   116.632               4        blues
# 51725   95.073               4      hip-hop
#
# [5 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df[df['album_name'].isna()]
# Out:
#        Unnamed: 0                track_id artists album_name track_name  \
# 65900       65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN
#
#        popularity  duration_ms  explicit  danceability  energy  ...  loudness  \
# 65900           0            0     False         0.501   0.583  ...     -9.46
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900     0       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature  track_genre
# 65900  138.391               4        k-pop
#
# [1 rows x 21 columns]

# %%
df.dropna(inplace=True)

# %%
df = df.iloc[:50000, :7]

# %%
df
# Out:
#        Unnamed: 0                track_id                           artists  \
# 0               0  5SuOikwiRyPMVoIQDJUgSV                       Gen Hoshino
# 1               1  4qPNDBW1i3p13qLCt0Ki3A                      Ben Woodward
# 2               2  1iJBSr7s7jYXzM8EGcbK5b            Ingrid Michaelson;ZAYN
# 3               3  6lfxq3CG4xtTiEg7opyCyx                      Kina Grannis
# 4               4  5vjLSffimiIP26QG5WcN2K                  Chord Overstreet
# ...           ...                     ...                               ...
# 49995       49995  2DWNZunMWTsEoox83agzO2  Noisecontrollers;Bass Modulators
# 49996       49996  5FbRok5VvNvgKFsockjSd7                       The Prophet
# 49997       49997  01pX5frQUf9ioZQQJjGNxU                       The Prophet
# 49998       49998  2DgNGXMJ92AHIaBWYXI7XW                     Brennan Heart
# 49999       49999  4W26Z7WlOdxPYgu1mJxcD7               Jebroer;Paul Elstak
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                Hold On
# ...                                                  ...
# 49995                                         All Around
# 49996          The Hardcore Archive Part 2 (1995 - 1996)
# 49997                 The Hardcore Archive Part 3 (1997)
# 49998                                 Evolution Of Style
# 49999  Kind Van De Duivel Vol. 2 - De Grootste Hardst...
#
#                                            track_name  popularity  duration_ms
# 0                                              Comedy          73       230666
# 1                                    Ghost - Acoustic          55       149610
# 2                                      To Begin Again          57       210826
# 3                          Can't Help Falling In Love          71       201933
# 4                                             Hold On          82       198853
# ...                                               ...         ...          ...
# 49995        Faster N Further - Bass Modulators Remix          19       219871
# 49996  I Can't Stand It (4 Minute Mix) - Extended Mix           9       240350
# 49997            Nonono (Original Mix) - Extended Mix           0       346429
# 49998                F.I.F.O. (Outbreak Remix) - Edit          19       185600
# 49999                              Kind Eines Teufels          20       203079
#
# [50000 rows x 7 columns]

# %%
df.to_csv("spotify-clean.csv")
